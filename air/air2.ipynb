# %%
import pandas as pd
dh = pd.read_csv(r"F:\dektop241205\health_app\air\alizimber.csv", encoding="ISO-8859-1")
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.expand_frame_repr', False)  # Prevent column wrapping
dh.head()
# Out:
#         Country  Age  Gender  Education Level   BMI Physical Activity Level Smoking Status Alcohol Consumption Diabetes Hypertension Cholesterol Level Family History of Alzheimerâs  Cognitive Test Score Depression Level Sleep Quality Dietary Habits Air Pollution Exposure Employment Status Marital Status Genetic Risk Factor (APOE-Îµ4 allele) Social Engagement Level Income Level Stress Levels Urban vs Rural Living Alzheimerâs Diagnosis
# 0         Spain   90    Male                1  33.0                  Medium          Never        Occasionally       No           No            Normal                              No                    90              Low          Poor        Healthy                   High           Retired         Single                                    No                     Low       Medium          High                 Urban                      No
# ...

# %%
from matplotlib import axis


dh = dh.drop(columns=["Country"],axis=1)

# %%
dh.head()
# Out:
#    Age  Gender  Education Level   BMI Physical Activity Level Smoking Status Alcohol Consumption Diabetes Hypertension Cholesterol Level Family History of Alzheimerâs  Cognitive Test Score Depression Level Sleep Quality Dietary Habits Air Pollution Exposure Employment Status Marital Status Genetic Risk Factor (APOE-Îµ4 allele) Social Engagement Level Income Level Stress Levels Urban vs Rural Living Alzheimerâs Diagnosis
# 0   90    Male                1  33.0                  Medium          Never        Occasionally       No           No            Normal                              No                    90              Low          Poor        Healthy                   High           Retired         Single                                    No                     Low       Medium          High                 Urban                      No
# ...

# %%
odinaldata = dh.drop(columns=["Age",	"Gender",	"Education Level",	"BMI","Diabetes"	,"Hypertension","Family History of Alzheimerâs"	,"Cognitive Test Score","Genetic Risk Factor (APOE-Îµ4 allele)","Alzheimerâs Diagnosis"],axis=1)

# %%
odinaldata.head()
# Out:
#   Physical Activity Level Smoking Status Alcohol Consumption Cholesterol Level Depression Level Sleep Quality Dietary Habits Air Pollution Exposure Employment Status Marital Status Social Engagement Level Income Level Stress Levels Urban vs Rural Living
# 0                  Medium          Never        Occasionally            Normal              Low          Poor        Healthy                   High           Retired         Single                     Low       Medium          High                 Urban
# 1                  Medium         Former               Never            Normal              Low          Good        Healthy                 Medium        Unemployed        Widowed                    High          Low          High                 Urban
# ...

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
oe = OrdinalEncoder(categories=[["Low", "Medium", "High"],["Never","Former","Current"],["Never","Occasionally","Regularly"],["Normal","High"],["Low","Medium","High"],["Poor","Average","Good"],["Unhealthy","Average","Healthy"],["Low","Medium","High"],["Unemployed","Retired","Employed"],["Married","Single","Widowed"],["Low","Medium","High"],["Low","Medium","High"],["Low","Medium","High"],["Rural","Urban"]])

# %%
transformdata = oe.fit_transform(odinaldata)

# %%
transformdata
# Out:
# array([[1., 0., 1., ..., 1., 2., 1.],
#        [1., 1., 0., ..., 0., 2., 1.],
#        [2., 2., 1., ..., 1., 2., 0.],
#        ...,
#        [1., 0., 2., ..., 0., 0., 0.],
#        [0., 0., 2., ..., 0., 2., 0.],
#        [0., 2., 2., ..., 1., 1., 1.]])
